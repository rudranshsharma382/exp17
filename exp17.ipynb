# %% [markdown]
# #UNIT-4
# #EXP- 17
# #NAME-RUDRANSH SHARMA
# #PRN-25070123096
# #AIM-Basic charts and visual encoding

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd

data = {
    'Days': ['Mon', 'Tue', 'Wed', 'Thu', 'Fri'],
    'Study_Hours': [2, 3, 2.5, 4, 3.5],
    'Marks': [50, 60, 55, 70, 65],
    'Attendance': [60, 70, 65, 80, 75],
    'Sleep_Hours': [6, 7, 6, 8, 7],
    'Assignments_Completed': [1, 2, 1, 3, 2]
}
df = pd.DataFrame(data)
display(df)
# Out:
#   Days  Study_Hours  Marks  Attendance  Sleep_Hours  Assignments_Completed
# 0  Mon          2.0     50          60            6                      1
# 1  Tue          3.0     60          70            7                      2
# 2  Wed          2.5     55          65            6                      1
# 3  Thu          4.0     70          80            8                      3
# 4  Fri          3.5     65          75            7                      2

# %%
import matplotlib.pyplot as plt

#Line chart(Trend)

plt.plot(df['Days'], df['Study_Hours'],marker='o')
plt.title('Rudransh')
plt.xlabel('Days')
plt.ylabel('Study Hours')
plt.show()

# %%
import matplotlib.pyplot as plt
import pandas as pd

data = {
    'Days': ['Mon', 'Tue', 'Wed', 'Thu', 'Fri'],
    'Study_Hours': [2, 3, 2.5, 4, 3.5],
    'Marks': [50, 60, 55, 70, 65],
    'Attendance': [60, 70, 65, 80, 75],
    'Sleep_Hours': [6, 7, 6, 8, 7],
    'Assignments_Completed': [1, 2, 1, 3, 2]
}
df = pd.DataFrame(data)

#Advance line chart
plt.figure(figsize=(7,4))

plt.plot(df['Days'], df['Study_Hours'],
         marker='o',color='green', label='Study Hours')
plt.plot(df['Days'], df['Marks'],
         marker='o',color='red', label='Marks')
plt.title('Rudransh')
plt.xlabel('Days')
plt.ylabel('Study Hours')
plt.show()

# %%
from matplotlib.lines import lineStyles
#bar chart (Comparison)
plt.bar(df['Days'], df['Marks'],color='green',edgecolor='black')
plt.title('mrs comparison')
plt.xlabel('Days')
plt.ylabel('Study Hours')
plt.grid(axis='y',linestyle='--',alpha=0.5)
plt.show()
plt
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.12/dist-packages/matplotlib/pyplot.py'>

# %%
#advance bar graph

bars = plt.bar(df['Days'], df['Marks'],color='red')
for bar in bars:
    y = bar.get_height()
    plt.text(bar.get_x() + bar.get_width() / 2,y, str(y) ,ha='center',va='bottom')
plt.title('marks comparison')
plt.xlabel('Days')
plt.ylabel('Study Hours')
plt.grid(axis='y',linestyle='--',alpha=0.5) #ads horizontal grid for readability
plt.show()
plt
# Out:
# <module 'matplotlib.pyplot' from '/usr/local/lib/python3.12/dist-packages/matplotlib/pyplot.py'>

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

x = np.arange(len(df['Days']))
width = 0.36

plt.bar(x - width/2, df['Study_Hours'],width,label='Study Hours')
plt.bar(x + width/2, df['Marks'],width,label='Marks')

plt.xticks(x,df['Days'])
plt.title('Rudansh')
plt.xlabel('Days')
plt.legend()
plt.show()

# %%
import numpy as np
import matplotlib.pyplot as plt # Added import for matplotlib.pyplot
# Example data (more values for better histogram)
marks = [50, 60, 55, 70, 65, 75, 80, 85, 90, 45, 68, 72, 77, 82, 88] # Corrected ')' to ']'
# Calculate mean
mean_value = np.mean(marks) # Removed space
plt.figure(figsize=(7,4))
plt.hist(marks, bins=3, color='skyblue', edgecolor='black')
# Mean line
plt.axvline(mean_value, color='red', linestyle='--', linewidth=2, label='Mean')
plt.title("Advanced Histogram of Marks")
plt.xlabel("Marks") # Removed space
plt.ylabel("Frequency") # Added y-label for clarity
plt.legend()
plt.grid(axis='y',linestyle='-.',alpha=0.5)
plt.show() # Added plt.show() to display the plot

# %%
# 4. Scattter Plot (RelationShip)


import matplotlib.pyplot as plt
plt.scatter(df['Study_Hours'], df['Marks'])
plt.title('rudransh Ploted this graph')
plt.xlabel('Study Hours')
plt.ylabel('Marks')
plt.show()

# %%
# Conditional scatter plot
# Example category
df ['Result'] = ['Fail', 'Pass', 'Fail', 'Pass'
, 'Pass']
colors = ['red' if r=='Fail' else 'green' for r in df[ 'Result']]
plt.scatter(df["Study_Hours"], df['Marks'], color=colors)
plt.title("Rudransh")
plt.xlabel ("Study Hours")
plt.ylabel ("Marks")
plt.show()

# %%
#datast2
data = {
    'Day': ['Mon','Tue','Wed','Thu','Fri','Sat','Sun','Mon','Tue','Wed'],
    'Region': ['North','South','East','West','North','South','East','West','North',
               'South'],
    'Sales': [200,220,250,270,300,350,400,280,260,290],
    'Profit': [20,25,30,35,50,60,80,40,38,45],
    'Customers': [30,35,40,45,50,65,80,55,48,52],
    'Category': ['Food','Clothing','Electronics','Food','Clothing','Electronics',
                 'Food','Clothing','Electronics','Food']
}
df = pd.DataFrame(data)
display(df)
# Out:
#    Day Region  Sales  Profit  Customers     Category
# 0  Mon  North    200      20         30         Food
# 1  Tue  South    220      25         35     Clothing
# 2  Wed   East    250      30         40  Electronics
# 3  Thu   West    270      35         45         Food
# 4  Fri  North    300      50         50     Clothing
# 5  Sat  South    350      60         65  Electronics
# 6  Sun   East    400      80         80         Food
# 7  Mon   West    280      40         55     Clothing
# 8  Tue  North    260      38         48  Electronics
# 9  Wed  South    290      45         52         Food

# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

#datast2
data = {
    'Day': ['Mon','Tue','Wed','Thu','Fri','Sat','Sun','Mon','Tue','Wed'],
    'Region': ['North','South','East','West','North','South','East','West','North',
               'South'],
    'Sales': [200,220,250,270,300,350,400,280,260,290],
    'Profit': [20,25,30,35,50,60,80,40,38,45],
    'Customers': [30,35,40,45,50,65,80,55,48,52],
    'Category': ['Food','Clothing','Electronics','Food','Clothing','Electronics',
                 'Food','Clothing','Electronics','Food']
}
df = pd.DataFrame(data)

#Line plot
sns.lineplot(x='Day',y='Sales',data=df,errorbar=None)
plt.title('Rudransh')

plt.show()

# %%
#Histogram
sns.histplot(df['Sales'],bins=5,)
plt.title('Rudransh')
plt.show()
